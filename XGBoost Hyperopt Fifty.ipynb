# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

SEED = 314159265
VALID_SIZE = 0.2
TARGET = 'Diabetes_binary'
FEATURES = ['HighBP', 'PhysHlth', 'DiffWalk', 'BMI', 'GenHlth', 'HighChol', 'HeartDiseaseorAttack', 'Age']

def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(train_features, label=y_train)
    dvalid = xgb.DMatrix(valid_features, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          early_stopping_rounds = 10,
                          verbose_eval=False)
    predictions = gbm_model.predict(dvalid)
    score = roc_auc_score(y_valid, predictions)

    print("\tScore {0}\n\n".format(score))
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}


def optimize(
             trials, 
             random_state=SEED):
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        'nthread': 4,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'seed': random_state
    }
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials, 
                max_evals=50)
    return best


df = pd.read_csv(r"D:\CDC Diabetes\diabetes_binary_5050split_health_indicators_BRFSS2015.csv")

train_df, test_df = train_test_split(df.copy(),
                                                    shuffle = True,
                                                    random_state = 440,
                                                    test_size = .2,
                                                    stratify = df[TARGET].values)


train, valid = train_test_split(train_df, test_size=VALID_SIZE,
                                random_state=SEED)
train_features = train[FEATURES]
valid_features = valid[FEATURES]
y_train = train[TARGET]
y_valid = valid[TARGET]


trials = Trials()

best_hyperparams = optimize(
                            trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 5, 'min_child_weight': 4.0, 'n_estimators': 210.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8161256824676122
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 7, 'min_child_weight': 4.0, 'n_estimators': 146.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.8018597222894418
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 5, 'min_child_weight': 2.0, 'n_estimators': 128.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.813197607678779
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 8, 'min_child_weight': 4.0, 'n_estimators': 348.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.8114883512312836
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 11, 'min_child_weight': 4.0, 'n_estimators': 819.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.778668157505965
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 8, 'min_child_weight': 1.0, 'n_estimators': 185.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.7870732001970444
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 4, 'min_child_weight': 3.0, 'n_estimators': 354.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.814926686123489
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 11, 'min_child_weight': 5.0, 'n_estimators': 771.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7866757597734014
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 2, 'min_child_weight': 4.0, 'n_estimators': 418.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8221275581162824
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 1, 'min_child_weight': 5.0, 'n_estimators': 212.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8207351722393993
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.325, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 3, 'min_child_weight': 4.0, 'n_estimators': 158.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.8203022773286252
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 6.0, 'n_estimators': 934.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.8219017155344555
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 5, 'min_child_weight': 3.0, 'n_estimators': 925.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.8055930891638455
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 12, 'min_child_weight': 6.0, 'n_estimators': 648.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.8049968972634013
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 5, 'min_child_weight': 6.0, 'n_estimators': 461.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8094710565699791
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 3, 'min_child_weight': 4.0, 'n_estimators': 684.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.817937206664143
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 6, 'min_child_weight': 2.0, 'n_estimators': 170.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8152228123799815
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 9, 'min_child_weight': 3.0, 'n_estimators': 346.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.77418410283327
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 8, 'min_child_weight': 4.0, 'n_estimators': 959.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.7741458970279136
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 12, 'min_child_weight': 2.0, 'n_estimators': 887.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7933709207173887
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 510.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.8219903048548135
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 453.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8218205672792978
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 549.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8224748495122726
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 10, 'min_child_weight': 5.0, 'n_estimators': 589.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8116246665433575
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 13, 'min_child_weight': 6.0, 'n_estimators': 421.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7906442861936225
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 559.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.822314428900747
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 579.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.822326622242882
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 9, 'min_child_weight': 6.0, 'n_estimators': 720.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8073728012433957
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 7, 'min_child_weight': 5.0, 'n_estimators': 624.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8185414336644045
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 2, 'min_child_weight': 6.0, 'n_estimators': 291.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8223710028817558
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 6, 'min_child_weight': 6.0, 'n_estimators': 288.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8126594904783755
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 10, 'min_child_weight': 6.0, 'n_estimators': 259.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7931174867908588
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 4, 'min_child_weight': 6.0, 'n_estimators': 525.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8156750134158028
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 1, 'min_child_weight': 5.0, 'n_estimators': 283.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8206239627061316
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 7, 'min_child_weight': 6.0, 'n_estimators': 118.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8180989091398416
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 13, 'min_child_weight': 3.0, 'n_estimators': 346.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7859485207099851
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 2, 'min_child_weight': 5.0, 'n_estimators': 806.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8222801781153395
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 11, 'min_child_weight': 1.0, 'n_estimators': 737.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8045496673593735
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 2, 'min_child_weight': 4.0, 'n_estimators': 495.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8226794944377724
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 4, 'min_child_weight': 4.0, 'n_estimators': 479.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8215343207564323
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 1, 'min_child_weight': 3.0, 'n_estimators': 393.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7754589480184694
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 8, 'min_child_weight': 2.0, 'n_estimators': 635.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8044351750032234
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 3, 'min_child_weight': 4.0, 'n_estimators': 856.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8213129334342316
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 683.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.8227540301496955
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 11, 'min_child_weight': 3.0, 'n_estimators': 688.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.8013921857810123
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 5, 'min_child_weight': 1.0, 'n_estimators': 831.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.8165591245155335
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 6, 'min_child_weight': 3.0, 'n_estimators': 785.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7946477824937873
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 9, 'min_child_weight': 2.0, 'n_estimators': 988.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.7919463788087466
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 12, 'min_child_weight': 2.0, 'n_estimators': 741.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.7679365938705383
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 2, 'min_child_weight': 4.0, 'n_estimators': 683.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.801397485195094
#
#
# 100%|██████████| 50/50 [05:18<00:00,  6.38s/trial, best loss: 0.1772459698503045]
# The best hyperparameters are:
#
# {'colsample_bytree': 0.75, 'eta': 0.07500000000000001, 'gamma': 0.9, 'max_depth': 1, 'min_child_weight': 3.0, 'n_estimators': 683.0, 'subsample': 0.65}

# %%
fifty = xgb.XGBClassifier(colsample_bytree = 0.65,
                          eta = 0.025,
                          eval_metric = 'auc',
                          gamma = 0.7000000000000001, 
                          max_depth = 2, 
                          min_child_weight = 1, 
                          n_estimators = 438,
                          objective = 'binary:logistic',
                          seed = SEED,
                          subsample = 0.8,
                          tree_method = 'exact')

fifty.fit(train_features, y_train,
          eval_set = [(valid_features, y_valid)],
          verbose = False)

pred = fifty.predict(test_df[FEATURES])
pred_fifty = fifty.predict_proba(test_df[FEATURES])[:,1]

print("Accuracy: ", accuracy_score(test_df[TARGET], pred))
print("Recall: ", recall_score(test_df[TARGET], pred))
print("ROC AUC: ", roc_auc_score(test_df[TARGET], pred_fifty))
# Out:
# Accuracy:  0.747719074899215
# Recall:  0.7883717640401754
# ROC AUC:  0.8247246929288446
