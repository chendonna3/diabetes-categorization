# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

SEED = 314159265
VALID_SIZE = 0.2
TARGET = 'Diabetes_012'
FEATURES = ['HighBP', 'PhysHlth', 'DiffWalk', 'BMI', 'GenHlth', 'HighChol', 'HeartDiseaseorAttack', 'Age']

def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(train_features, label=y_train)
    dvalid = xgb.DMatrix(valid_features, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          early_stopping_rounds = 10,
                          verbose_eval=False)
    predictions = gbm_model.predict(dvalid)
    score = roc_auc_score(y_valid, predictions, multi_class = 'ovr')

    print("\tScore {0}\n\n".format(score))
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}


def optimize(
             trials, 
             random_state=SEED):
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'eval_metric': 'auc',
        'objective': 'multi:softprob',
        'nthread': 4,
        'num_class': 3,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'seed': random_state
    }
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials, 
                max_evals=50)
    return best


df = pd.read_csv(r"D:\CDC Diabetes\diabetes_012_health_indicators_BRFSS2015.csv")

train_df, test_df = train_test_split(df.copy(),
                                                    shuffle = True,
                                                    random_state = 440,
                                                    test_size = .2,
                                                    stratify = df[TARGET].values)


train, valid = train_test_split(train_df, test_size=VALID_SIZE,
                                random_state=SEED)
train_features = train[FEATURES]
valid_features = valid[FEATURES]
y_train = train[TARGET]
y_valid = valid[TARGET]


trials = Trials()

best_hyperparams = optimize(
                            trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 7, 'min_child_weight': 3.0, 'n_estimators': 757.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.764993313712468
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 10, 'min_child_weight': 6.0, 'n_estimators': 406.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.7323910926413157
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 6, 'min_child_weight': 5.0, 'n_estimators': 834.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7756058713550971
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 12, 'min_child_weight': 4.0, 'n_estimators': 554.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.7491688802545595
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 4, 'min_child_weight': 3.0, 'n_estimators': 141.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7774843484714741
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 7, 'min_child_weight': 4.0, 'n_estimators': 574.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7624632922741957
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 4, 'min_child_weight': 4.0, 'n_estimators': 947.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7772600143456586
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 2, 'min_child_weight': 6.0, 'n_estimators': 126.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7809881901501079
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 12, 'min_child_weight': 5.0, 'n_estimators': 203.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.741171151646082
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 7, 'min_child_weight': 5.0, 'n_estimators': 554.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7623990787859318
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 8, 'min_child_weight': 5.0, 'n_estimators': 446.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7359955153322165
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 11, 'min_child_weight': 5.0, 'n_estimators': 863.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7367089524698726
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 12, 'min_child_weight': 2.0, 'n_estimators': 476.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7421969184952277
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 9, 'min_child_weight': 1.0, 'n_estimators': 538.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.7326502290633988
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 10, 'min_child_weight': 6.0, 'n_estimators': 161.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.754564626985616
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 1, 'min_child_weight': 1.0, 'n_estimators': 461.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.7774363877003351
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 6, 'min_child_weight': 6.0, 'n_estimators': 537.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7519005395022104
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 6, 'min_child_weight': 6.0, 'n_estimators': 904.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7685587588722341
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 7, 'min_child_weight': 6.0, 'n_estimators': 927.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7373008565034468
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 7, 'min_child_weight': 2.0, 'n_estimators': 530.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7519657436214153
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 244.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7816275585184993
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 292.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7812320380311664
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 307.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7811090867437848
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 3, 'min_child_weight': 3.0, 'n_estimators': 285.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7807214993721433
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 267.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7817264756137301
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 13, 'min_child_weight': 1.0, 'n_estimators': 651.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7235137225741038
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 5, 'min_child_weight': 3.0, 'n_estimators': 359.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7651122869197445
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 216.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7817899421513969
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 733.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7808979349095125
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 9, 'min_child_weight': 1.0, 'n_estimators': 358.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7431524466596521
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 11, 'min_child_weight': 2.0, 'n_estimators': 210.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7514794963838757
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.325, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 2, 'min_child_weight': 1.0, 'n_estimators': 375.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7816271218650211
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 8, 'min_child_weight': 3.0, 'n_estimators': 683.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7443871417544724
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 13, 'min_child_weight': 2.0, 'n_estimators': 197.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.759821103744402
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 3, 'min_child_weight': 4.0, 'n_estimators': 414.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7778965775912958
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 1, 'min_child_weight': 1.0, 'n_estimators': 100.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.7771252633488306
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 5, 'min_child_weight': 3.0, 'n_estimators': 622.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7630498466522425
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 10, 'min_child_weight': 4.0, 'n_estimators': 103.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.75334430816534
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 4, 'min_child_weight': 2.0, 'n_estimators': 258.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7749713622230803
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 324.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7813595813828077
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.325, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 2, 'min_child_weight': 1.0, 'n_estimators': 136.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7814539931209891
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 8, 'min_child_weight': 2.0, 'n_estimators': 766.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7408000185130897
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 12, 'min_child_weight': 3.0, 'n_estimators': 161.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7492686120416279
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 4, 'min_child_weight': 4.0, 'n_estimators': 498.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.7735577991103139
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 2, 'min_child_weight': 1.0, 'n_estimators': 419.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7817747348084204
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 11, 'min_child_weight': 1.0, 'n_estimators': 998.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.759266959144445
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 1, 'min_child_weight': 1.0, 'n_estimators': 410.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.7773483159605648
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 10, 'min_child_weight': 1.0, 'n_estimators': 439.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.7735532538601589
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 9, 'min_child_weight': 1.0, 'n_estimators': 496.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7386095648690354
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 6, 'min_child_weight': 2.0, 'n_estimators': 602.0, 'nthread': 4, 'num_class': 3, 'objective': 'multi:softprob', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.7640302010651107
#
#
# 100%|██████████| 50/50 [47:18<00:00, 56.78s/trial, best loss: 0.21821005784860315]
# The best hyperparameters are:
#
# {'colsample_bytree': 0.65, 'eta': 0.45, 'gamma': 0.65, 'max_depth': 1, 'min_child_weight': 2.0, 'n_estimators': 216.0, 'subsample': 0.9500000000000001}

# %%
multi = xgb.XGBClassifier(colsample_bytree = 0.6000000000000001,
                          eta = 0.07500000000000001,
                          eval_metric =  'auc',
                          gamma = 0.6000000000000001, 
                          max_depth = 1, 
                          min_child_weight = 4, 
                          n_estimators = 554,
                          num_class = 3,
                          objective = 'multi:softprob',
                          subsample = 0.65,
                          seed = SEED,
                          tree_method = 'exact')

multi.fit(train_features, y_train, 
          eval_set = [(valid_features, y_valid)],
          verbose = False)

pred = multi.predict(test_df[FEATURES])
pred_multi = multi.predict_proba(test_df[FEATURES])

print("Accuracy: ", accuracy_score(test_df[TARGET], pred))
print("Recall: ", recall_score(test_df[TARGET], pred, average = 'micro'))
print("ROC AUC: ", roc_auc_score(test_df[TARGET], pred_multi, multi_class='ovr'))
# Out:
# Accuracy:  0.8489632608010091
# Recall:  0.8489632608010091
# ROC AUC:  0.7760194294480312
