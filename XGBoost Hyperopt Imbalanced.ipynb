# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

SEED = 314159265
VALID_SIZE = 0.2
TARGET = 'Diabetes_binary'
FEATURES = ['HighBP', 'PhysHlth', 'DiffWalk', 'BMI', 'GenHlth', 'HighChol', 'HeartDiseaseorAttack', 'Age']

def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(train_features, label=y_train)
    dvalid = xgb.DMatrix(valid_features, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          early_stopping_rounds = 10,
                          verbose_eval=False)
    predictions = gbm_model.predict(dvalid)
    score = roc_auc_score(y_valid, predictions)

    print("\tScore {0}\n\n".format(score))
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}


def optimize(
             trials, 
             random_state=SEED):
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        'nthread': 4,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'seed': random_state
    }
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials, 
                max_evals=50)
    return best


df = pd.read_csv(r"D:\CDC Diabetes\diabetes_binary_health_indicators_BRFSS2015.csv")

train_df, test_df = train_test_split(df.copy(),
                                                    shuffle = True,
                                                    random_state = 440,
                                                    test_size = .2,
                                                    stratify = df[TARGET].values)


train, valid = train_test_split(train_df, test_size=VALID_SIZE,
                                random_state=SEED)
train_features = train[FEATURES]
valid_features = valid[FEATURES]
y_train = train[TARGET]
y_valid = valid[TARGET]


trials = Trials()

best_hyperparams = optimize(
                            trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 8, 'min_child_weight': 4.0, 'n_estimators': 251.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8072607338690805
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.325, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 2, 'min_child_weight': 1.0, 'n_estimators': 112.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.8288781422295777
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 1, 'min_child_weight': 5.0, 'n_estimators': 831.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8260993416058602
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 13, 'min_child_weight': 6.0, 'n_estimators': 686.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7756358191747758
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.47500000000000003, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 10, 'min_child_weight': 4.0, 'n_estimators': 144.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.7953894254309721
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.55, 'max_depth': 1, 'min_child_weight': 4.0, 'n_estimators': 345.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8260573612232173
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 6, 'min_child_weight': 4.0, 'n_estimators': 922.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8145748265117747
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 3, 'min_child_weight': 1.0, 'n_estimators': 126.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.828837477118783
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 5, 'min_child_weight': 4.0, 'n_estimators': 814.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8232012458254947
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 8, 'min_child_weight': 1.0, 'n_estimators': 656.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8011208153530084
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 472.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8296109523873139
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 5, 'min_child_weight': 5.0, 'n_estimators': 332.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8276104342217848
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.4, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 10, 'min_child_weight': 5.0, 'n_estimators': 743.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.7812791271464012
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 13, 'min_child_weight': 4.0, 'n_estimators': 866.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.7938728963580741
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 9, 'min_child_weight': 4.0, 'n_estimators': 378.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.8197938200482194
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.325, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 5, 'min_child_weight': 2.0, 'n_estimators': 761.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.817810454574972
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.30000000000000004, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 8, 'min_child_weight': 1.0, 'n_estimators': 670.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8107284970976593
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 12, 'min_child_weight': 4.0, 'n_estimators': 798.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8188638764300551
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.45, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 9, 'min_child_weight': 3.0, 'n_estimators': 190.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.7974312405535757
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.65, 'max_depth': 10, 'min_child_weight': 5.0, 'n_estimators': 795.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.7843665472829655
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 506.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.829349698134795
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 502.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.8290426595271304
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 525.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8292901369517787
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 4, 'min_child_weight': 3.0, 'n_estimators': 440.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8267645158430168
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 7, 'min_child_weight': 3.0, 'n_estimators': 579.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8153636543554299
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.375, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 11, 'min_child_weight': 2.0, 'n_estimators': 602.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 1.0, 'tree_method': 'exact'}
# 	Score 0.7925975752473471
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 489.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.8291991562453724
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 424.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9500000000000001, 'tree_method': 'exact'}
# 	Score 0.8291874941683167
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.42500000000000004, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 11, 'min_child_weight': 3.0, 'n_estimators': 294.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.7863815566495064
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.35000000000000003, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 281.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.829163561378605
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 3, 'min_child_weight': 3.0, 'n_estimators': 230.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.8293938732161497
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 3, 'min_child_weight': 3.0, 'n_estimators': 204.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.8293656541875909
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 3, 'min_child_weight': 6.0, 'n_estimators': 229.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.8293605194694533
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 3, 'min_child_weight': 3.0, 'n_estimators': 161.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.5, 'tree_method': 'exact'}
# 	Score 0.8288513029469775
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 6, 'min_child_weight': 3.0, 'n_estimators': 431.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8213247655321614
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 12, 'min_child_weight': 5.0, 'n_estimators': 384.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.8057170947223196
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 1, 'min_child_weight': 1.0, 'n_estimators': 253.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.8260839219776612
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 7, 'min_child_weight': 6.0, 'n_estimators': 607.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.825446912610811
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 4, 'min_child_weight': 3.0, 'n_estimators': 336.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.55, 'tree_method': 'exact'}
# 	Score 0.827782724518065
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 13, 'min_child_weight': 4.0, 'n_estimators': 123.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8189544986604085
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'max_depth': 3, 'min_child_weight': 1.0, 'n_estimators': 985.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.828760231976817
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 8, 'min_child_weight': 5.0, 'n_estimators': 461.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# 	Score 0.8057622936525446
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.65, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 4.0, 'n_estimators': 558.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8215547137357244
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.1, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 1, 'min_child_weight': 4.0, 'n_estimators': 715.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.65, 'tree_method': 'exact'}
# 	Score 0.8260928529314082
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'max_depth': 3, 'min_child_weight': 2.0, 'n_estimators': 383.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.829158341554642
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 9, 'min_child_weight': 3.0, 'n_estimators': 645.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.7000000000000001, 'tree_method': 'exact'}
# 	Score 0.8196513864228974
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.275, 'eval_metric': 'auc', 'gamma': 0.75, 'max_depth': 5, 'min_child_weight': 4.0, 'n_estimators': 318.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8500000000000001, 'tree_method': 'exact'}
# 	Score 0.8238848777109234
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.55, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'max_depth': 10, 'min_child_weight': 2.0, 'n_estimators': 875.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.9, 'tree_method': 'exact'}
# 	Score 0.8041599624337729
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.125, 'eval_metric': 'auc', 'gamma': 0.8, 'max_depth': 13, 'min_child_weight': 1.0, 'n_estimators': 254.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.75, 'tree_method': 'exact'}
# 	Score 0.797027294779294
#
#
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.6000000000000001, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.9, 'max_depth': 12, 'min_child_weight': 5.0, 'n_estimators': 104.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 314159265, 'subsample': 0.8, 'tree_method': 'exact'}
# 	Score 0.821930161953291
#
#
# 100%|██████████| 50/50 [18:11<00:00, 21.82s/trial, best loss: 0.17038904761268614]
# The best hyperparameters are:
#
# {'colsample_bytree': 0.75, 'eta': 0.17500000000000002, 'gamma': 0.9, 'max_depth': 1, 'min_child_weight': 3.0, 'n_estimators': 472.0, 'subsample': 0.8500000000000001}

# %%
imbal = xgb.XGBClassifier(colsample_bytree = 0.8500000000000001,
                          eta = 0.125,
                          eval_metric = 'auc',
                          gamma = 0.75, 
                          max_depth = 1, 
                          min_child_weight = 3, 
                          n_estimators = 642,
                          objective = 'binary:logistic',
                          subsample = 0.7000000000000001,
                          seed = SEED,
                          tree_method = 'exact')

imbal.fit(train_features, y_train, 
          eval_set = [(valid_features, y_valid)],
          verbose = False)

pred = imbal.predict(test_df[FEATURES])
pred_imbal = imbal.predict_proba(test_df[FEATURES])[:,1]

print("Accuracy: ", accuracy_score(test_df[TARGET], pred))
print("Recall: ", recall_score(test_df[TARGET], pred, average = 'micro'))
print("ROC AUC: ", roc_auc_score(test_df[TARGET], pred_imbal))
# Out:
# Accuracy:  0.8656575212866604
# Recall:  0.8656575212866604
# ROC AUC:  0.8209993540828906
